# %% [markdown]
# ## Questions:
# - how is the best way to decode the geographic coordinates of the data? (metadata through link to data page: https://www.sciencebase.gov/catalog/item/597230e4e4b0ec1a4885edc1)
# - is there a way to graph this on a cartopy map? (if so need to install cartopy in environment)
# - also some fixed reference point would be nice to see how the lava flow is moving

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

# %%
may24_16 = gpd.read_file('data/05_2016-17_kilauea_lava_shapefiles/Ep61g_20160524_flow.shp').to_crs(4326)
jun10_16 = gpd.read_file('data/05_2016-17_kilauea_lava_shapefiles/Ep61g_20160610_flow.shp').to_crs(4326)
jun30_16 = gpd.read_file('data/05_2016-17_kilauea_lava_shapefiles/Ep61g_20160630_flow.shp').to_crs(4326)
jul19_16 = gpd.read_file('data/05_2016-17_kilauea_lava_shapefiles/Ep61g_20160719_flow.shp').to_crs(4326)

aug19_16 = gpd.read_file('data/05_2016-17_kilauea_lava_shapefiles/Ep61g_20160819_flow.shp').to_crs(4326)
sep20_16 = gpd.read_file('data/05_2016-17_kilauea_lava_shapefiles/Ep61g_20160920_flow.shp').to_crs(4326)
oct19_16 = gpd.read_file('data/05_2016-17_kilauea_lava_shapefiles/Ep61g_20161019_flow.shp').to_crs(4326)

nov29_16 = gpd.read_file('data/05_2016-17_kilauea_lava_shapefiles/Ep61g_20161129_flow.shp').to_crs(4326)
dec14_16 = gpd.read_file('data/05_2016-17_kilauea_lava_shapefiles/Ep61g_20161214_flow.shp').to_crs(4326)
jan12_17 = gpd.read_file('data/05_2016-17_kilauea_lava_shapefiles/Ep61g_20170112_flow.shp').to_crs(4326)
feb24_17 = gpd.read_file('data/05_2016-17_kilauea_lava_shapefiles/Ep61g_20170224_flow.shp').to_crs(4326)

mar30_17 = gpd.read_file('data/05_2016-17_kilauea_lava_shapefiles/Ep61g_20170330_flow.shp').to_crs(4326)
may03_17 = gpd.read_file('data/05_2016-17_kilauea_lava_shapefiles/Ep61g_20170503_flow.shp').to_crs(4326)
may31_17 = gpd.read_file('data/05_2016-17_kilauea_lava_shapefiles/Ep61g_20170531_flow.shp').to_crs(4326)

# %%
fig, axes = plt.subplots(2, 7, figsize=(18, 12))
[ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9, ax10, ax11, ax12, ax13, ax14] = axes.flatten()

may24_16.plot(ax=ax1)
ax1.set_title('May 24, 2016')
ax1.set_xlim([-155.100453,-155.034902])
ax1.set_ylim([19.315307, 19.396264])

jun10_16.plot(ax=ax2)
ax2.set_title('June 10, 2016')
ax2.set_xlim([-155.100453,-155.034902])
ax2.set_ylim([19.315307, 19.396264])

jun30_16.plot(ax=ax3)
ax3.set_title('June 30, 2016')
ax3.set_xlim([-155.100453,-155.034902])
ax3.set_ylim([19.315307, 19.396264])

jul19_16.plot(ax=ax4)
ax4.set_title('July 19, 2016')
ax4.set_xlim([-155.100453,-155.034902])
ax4.set_ylim([19.315307, 19.396264])

aug19_16.plot(ax=ax5)
ax5.set_title('August 19, 2016')
ax5.set_xlim([-155.100453,-155.034902])
ax5.set_ylim([19.315307, 19.396264])

sep20_16.plot(ax=ax6)
ax6.set_title('September 20, 2016')
ax6.set_xlim([-155.100453,-155.034902])
ax6.set_ylim([19.315307, 19.396264])

oct19_16.plot(ax=ax7)
ax7.set_title('October 19, 2016')
ax7.set_xlim([-155.100453,-155.034902])
ax7.set_ylim([19.315307, 19.396264])

nov29_16.plot(ax=ax8)
ax8.set_title('November 29, 2016')
ax8.set_xlim([-155.100453,-155.034902])
ax8.set_ylim([19.315307, 19.396264])

dec14_16.plot(ax=ax9)
ax9.set_title('December 14, 2016')
ax9.set_xlim([-155.100453,-155.034902])
ax9.set_ylim([19.315307, 19.396264])

jan12_17.plot(ax=ax10)
ax10.set_title('January 12, 2017')
ax10.set_xlim([-155.100453,-155.034902])
ax10.set_ylim([19.315307, 19.396264])

feb24_17.plot(ax=ax11)
ax11.set_title('February 24, 2017')
ax11.set_xlim([-155.100453,-155.034902])
ax11.set_ylim([19.315307, 19.396264])

mar30_17.plot(ax=ax12)
ax12.set_title('March 30, 2017')
ax12.set_xlim([-155.100453,-155.034902])
ax12.set_ylim([19.315307, 19.396264])

may03_17.plot(ax=ax13)
ax13.set_title('May 3, 2017')
ax13.set_xlim([-155.100453,-155.034902])
ax13.set_ylim([19.315307, 19.396264])

may31_17.plot(ax=ax14)
ax14.set_title('May 31, 2017')
ax14.set_xlim([-155.100453,-155.034902])
ax14.set_ylim([19.315307, 19.396264])

plt.subplots_adjust(hspace=-0.45)
plt.show()

# %%
plume_data_2008_2015 = pd.read_csv('data/plume_heights/EruptionPlumeHeights_2008-2015.csv')
plume_data_2008_2015.head()
# Out:
#         Date (HST)  Inclination angle (degrees)  Distance (km)  \
# 0  3/31/2008 15:13                          7.0            2.0
# 1    4/1/2008 9:38                         12.5            1.6
# 2   4/1/2008 15:03                          9.0            1.6
# 3    4/2/2008 9:42                         12.0            1.6
# 4   4/2/2008 15:07                         10.5            1.8
#
#    Ht above vent elevation (m)
# 0                        451.0
# 1                        560.0
# 2                        458.0
# 3                        545.0
# 4                        539.0

# %%
# convert dates from file into numpy datetime64 format
new_dates = []

for dates in plume_data_2008_2015['Date (HST)']:
    date = dates.split(' ')[0]
    date_split = date.split('/')
    month = date_split[0]
    day = date_split[1]
    if len(day) == 1:
        day = f'0{day}'
    if len(month) == 1:
        month = f'0{month}'
    year = date_split[2]
    time = dates.split(' ')[1]
    times = time.split(':')
    hour = times[0]
    if len(hour) == 1:
        hour = f'0{hour}'
    minute = times[1]
    new_dates.append(f'{year}-{month}-{day}T{hour}:{minute}')
date_array = np.array(new_dates, dtype='datetime64')
#print(date_array)

# %%
# put new dates into plume data file
plume_data_2008_2015['date_new'] = date_array
plume_data_2008_2015 = plume_data_2008_2015.set_index('date_new')
plume_data_2008_2015 = plume_data_2008_2015.dropna()

# %%
fig, ax = plt.subplots(1, 1, figsize=(6,4))
ax.plot(plume_data_2008_2015['Ht above vent elevation (m)'])
ax.set_ylabel('Height Above Vent (m)')
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(6,4))
ax.plot(plume_data_2008_2015['Ht above vent elevation (m)'], linestyle='None',  marker='o', color='red')
ax.set_ylabel('Height Above Vent (m)')
plt.show()

# %%
plume_data_2018 = pd.read_csv('data/plume_heights/EruptionPlumeHeights_Apr-Aug2018.csv')

# %%
plume_data_2018.head()
# Out:
#       Date  (HST)  Max plume ht above HMM (m)  Max plume ht camera frame (m)  \
# 0             NaN                         NaN                            NaN
# 1  4/9/2018 17:41                         0.0                          187.0
# 2  4/9/2018 17:43                         0.0                          173.0
# 3  4/9/2018 17:51                         0.0                          177.0
# 4  4/9/2018 17:53                         0.0                          159.0
#
#    Unnamed: 3  \
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
#    *if 'max plume ht above HMM' is 0, highest plume is 'max plume ht camera frame'. If 'max plume ht camera frame' is 0, then highest plume is 'max plume ht above HMM'.
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
plume_data_2018['Date (HST)']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/volcan25/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date (HST)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 plume_data_2018['Date (HST)']
#
# File /opt/anaconda3/envs/volcan25/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /opt/anaconda3/envs/volcan25/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Date (HST)'

# %%
# convert dates from file into numpy datetime64 format
new_dates = []

for dates in plume_data_2018['Date (HST)']:
    date = dates.split(' ')[0]
    date_split = date.split('/')
    month = date_split[0]
    day = date_split[1]
    if len(day) == 1:
        day = f'0{day}'
    if len(month) == 1:
        month = f'0{month}'
    year = date_split[2]
    time = dates.split(' ')[1]
    times = time.split(':')
    hour = times[0]
    if len(hour) == 1:
        hour = f'0{hour}'
    minute = times[1]
    new_dates.append(f'{year}-{month}-{day}T{hour}:{minute}')
date_array = np.array(new_dates, dtype='datetime64')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/volcan25/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date (HST)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[87], line 4
#       1 # convert dates from file into numpy datetime64 format
#       2 new_dates = []
# ----> 4 for dates in plume_data_2018['Date (HST)']:
#       5     date = dates.split(' ')[0]
#       6     date_split = date.split('/')
#
# File /opt/anaconda3/envs/volcan25/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /opt/anaconda3/envs/volcan25/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Date (HST)'
