# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
gdf1 = gpd.read_file('data/05_2016-17_kilauea_lava_shapefiles/Ep61g_20160524_contacts.shp')
print(gdf1.shape)
print(gdf1.head())
# Out:
# (4, 6)
#   LineType  AccuracyMe       Source SourceDate   SHAPE_Leng  \
# 0  contact        10.0   Ortho, HVO 2016-05-24  2418.790131
# 1  contact        10.0  GPS, ground 2016-06-08   220.843866
# 2  contact        10.0   Ortho, HVO 2016-05-24    23.752758
# 3  contact        10.0  GPS, ground 2016-06-08    40.055374
#
#                                             geometry
# 0  LINESTRING (279560.672 2145498.323, 279561.184...
# 1  LINESTRING (279450.411 2145434.168, 279449.471...
# 2  LINESTRING (279457.881 2145424.268, 279460.184...
# 3  LINESTRING (279478.606 2145401.011, 279477.614...

# %%
# Data exploration plot of the first lava flow shapefile
gdf1.plot()
plt.show()

# %%
# Visualization of one of the other data shapefiles
gdf2 = gpd.read_file('data/05_2016-17_kilauea_lava_shapefiles/Ep61g_20160610_flow.shp')
gdf2.plot()
plt.show()
